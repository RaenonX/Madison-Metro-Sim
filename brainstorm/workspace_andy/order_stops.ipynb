# %%
import requests
from bs4 import BeautifulSoup

# %%
# Direction: North/West
# Service Type: Weekday/Weekend/Holiday
schedule = "https://www.cityofmadison.com/metro/routes-schedules/route-2"

# very clear interactive map of stops
"https://moovitapp.com/madison_wi-1503/poi/Madison%20Metro%20Bus%20Route%202/Casimir%20Jones%20Sc/en?tll=43.114017_-89.358725&fll=43.05913_-89.46963&customerId=4908&ref=1&poiType=efsite"

# bus stops name (sorted by name) and an interactive map:
"http://webwatch.cityofmadison.com/TMWebWatch/LiveADAArrivalTimes"

# bus routes (grouped by service type) and useful notes:
"https://en.wikipedia.org/wiki/Madison_Metro"

r = requests.get(schedule)
r.raise_for_status()

# %%
r.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">\r\n<head>\r\n  <link rel="profile" href="http://www.w3.org/1999/xhtml/vocab" />\r\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="canonical" href="/metro/routes-schedules/route-2" />\n<link rel="shortlink" href="/node/49282" />\n<meta about="/metro" typeof="skos:Concept" property="rdfs:label skos:prefLabel" content="Metro Transit" />\n<link rel="shortcut icon" href="https://www.cityofmadison.com/sites/default/files/template/favicon.
# ...

# %%
# find table
doc = BeautifulSoup(r.text, "html.parser")
element = doc.find_all("table")

# %%
element[0]s
# Out:
# <table border="0" cellpadding="0" cellspacing="0">
# <thead>
# <tr>
# <th scope="col"><span dir="ltr" lang="en">From Route</span> <span dir="ltr" lang="es">De la Ruta</span></th>
# <th scope="col">West Transfer Point</th>
# <th scope="col">Sheboygan &amp; Eau Claire</th>
# <th scope="col">University Bay &amp; University</th>
# <th scope="col">University &amp; Breese</th>
# <th scope="col">Main &amp; Carroll</th>
# <th scope="col">Johnson &amp; Ingersoll</th>
# <th scope="col">Fordem &amp; McGuire</th>
# <th scope="col">Sherman &amp; Sherman Ter</th>
# <th scope="col">North Transfer Point</th>
# <th scope="col"><span dir="ltr" lang="en">To Route</span> <span dir="ltr" lang="es">A la Ruta</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td> </td>
# <td><span class="transfer">W</span></td>
# <td><span class="stop">2</span></td>
# <td><span class="stop">3</span></td>
# <td><span class="stop">4</span></td>
# <td><span class="square">5</span></td>
# <td><span class="stop">6</span></td>
# ...
