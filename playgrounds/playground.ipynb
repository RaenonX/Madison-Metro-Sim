# %%
import functions
import pandas as pd
import geopandas as gpd

from collections import defaultdict, OrderedDict

pd.set_option('display.max_columns', None)

# %%
ax = functions.plot_background()
functions.plot_route(ax=ax, route_num=80)
# Out:
# <AxesSubplot:>

# %%
colored = gpd.read_file("../data_andy/Bus_Stops_and_Routes_Info/colored_routes-shp")
colored.head()
# Out:
#    OBJECTID  trips_rout  route_shor  \
# 0       712        8703           1
# 1       712        8703           1
# 2       713        8704           2
# 3       713        8704           2
# 4       714        8705           3
#
#                                           route_url_    ShapeSTLen  route_id  \
# 0  http://www.cityofmadison.com/metro/routes-sche...  32379.426307      9027
# 1  http://www.cityofmadison.com/metro/routes-sche...  32379.426307      9278
# 2  http://www.cityofmadison.com/metro/routes-sche...  96906.965534      9028
# 3  http://www.cityofmadison.com/metro/routes-sche...  96906.965534      9279
# 4  http://www.cityofmadison.com/metro/routes-sche...  76436.645959      9029
#
#    service_id agency_id  route_sh_1 route_long        route_serv  \
# 0          92       MMT           1       None  OLD UNIV:CAP SQR
# 1          93       MMT           1       None  OLD UNIV:CAP SQR
# 2          92       MMT           2       None  WEST TP:NORTH TP
# ...

# %%
# FIND overlap routes > than some threshold
# stop location
 # gemetry: multistring

stops_2019 = gpd.read_file("../data_andy/Bus_Stops_and_Routes_Info/Metro_Transit_Ridership_by_Stop-shp")

# %%
stops = gpd.read_file("../data_andy/Bus_Stops_and_Routes_Info/Metro_Transit_Bus_Stops-shp")
stops.head()
# Out:
#    OBJECTID  stop_id stop_code                      stop_name  \
# 0     12792     1110      1110      E Dayton & Wisconsin (WB)
# 1     12793     1111      1111     W Doty & M L K Junior (EB)
# 2     12794     1124      1124      S Fairchild & W Main (SB)
# 3     12795     1135      1135     N Webster & E Mifflin (NB)
# 4     12796     1140      1140  E Washington & N Webster (WB)
#
#                                            stop_desc   stop_lat   stop_lon  \
# 0  This EVENT/DETOUR ONLY stop (#1110) is westbou...  43.076428 -89.385920
# 1  This EVENT/DETOUR ONLY stop (#1111) is eastbou...  43.072938 -89.382354
# 2  This EVENT/DETOUR ONLY stop (#1124) is southbo...  43.072467 -89.385273
# 3  This EVENT/DETOUR ONLY stop (#1135) is northbo...  43.077272 -89.383413
# 4  This EVENT/DETOUR ONLY stop (#1140) is westbou...  43.076390 -89.381930
#
#   agency_id  location_t  parent_sta  wheelchair Route Route_Dir  Shelter  \
# ...

# %%
route_num = 80
ax = functions.plot_route(functions.plot_background(), route_num)
route_80 = functions.find_stop_of_route(route_num)
route_80.set_geometry("geometry").plot(ax=ax, markersize=2, zorder=2)
# stop_with_route.head()
# Out:
# <AxesSubplot:>

# %%
# TODO:
# extract important columns from the datesets to
# optimize the runtime
# route_short_name = range(1, 84)
def plot_stop():
    pass

# %%
def plot_duplicate_routes():
    pass

# %%
def plot_stop():
    pass


def plot_route(route_num): # TODO, add bus stop
    pass

# %%
def plot_duplicate_routes():
    pass
